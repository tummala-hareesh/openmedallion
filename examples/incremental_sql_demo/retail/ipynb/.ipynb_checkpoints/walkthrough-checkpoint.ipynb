# %% [markdown]
# # incremental_sql_demo — Pipeline Walkthrough
#
# **Observe how OpenMedallion handles growing datasets — run the pipeline twice.**
#
# | Run | What loads |
# |-----|------------|
# | Run 1 | Full load — 5 orders, 3 customers |
# | Run 2 | Delta only — 2 new orders + Charlie's tier update |
#
# **Data layout after bronze runs:**
# ```
# data/
# ├── retail.db
# ├── bronze/
# │   ├── orders/             ← dlt raw shards
# │   ├── customers/          ← dlt raw shards
# │   ├── orders.parquet      ← merged by bronze.py  ← silver reads this
# │   └── customers.parquet   ← merged by bronze.py  ← silver reads this
# ├── silver/
# └── gold/
# ```
#
# Run cells top to bottom.

# %% [markdown]
# ## Setup — navigate to example root

# %%
import os, sqlite3
from pathlib import Path

# Two levels up: ipynb/ → retail/ → incremental_sql_demo/
example_root = Path(os.getcwd()).parent.parent
os.chdir(example_root)
print(f'Working directory: {os.getcwd()}')
# Out:
# Working directory: /workspace/openmedallion/examples/incremental_sql_demo

# %% [markdown]
# ## Setup — create SQLite database
#
# Creates `data/retail.db` with 5 orders and 3 customers.

# %%
import polars as pl

DB = Path('data/retail.db')
DB.parent.mkdir(parents=True, exist_ok=True)

con = sqlite3.connect(DB)
cur = con.cursor()

cur.execute("""
    CREATE TABLE IF NOT EXISTS orders (
        order_id    INTEGER PRIMARY KEY,
        customer_id INTEGER NOT NULL,
        amount      REAL    NOT NULL,
        created_at  TEXT    NOT NULL
    )
""")
cur.execute("""
    CREATE TABLE IF NOT EXISTS customers (
        customer_id INTEGER PRIMARY KEY,
        name        TEXT NOT NULL,
        email       TEXT NOT NULL,
        tier        TEXT NOT NULL
    )
""")
cur.executemany('INSERT OR REPLACE INTO orders VALUES (?,?,?,?)', [
    (1, 101, 150.00, '2024-01-05'),
    (2, 102,  45.50, '2024-01-06'),
    (3, 101, 300.00, '2024-01-07'),
    (4, 103,  80.00, '2024-01-08'),
    (5, 102, 200.00, '2024-01-09'),
])
cur.executemany('INSERT OR REPLACE INTO customers VALUES (?,?,?,?)', [
    (101, 'Alice',   'alice@example.com',   'gold'),
    (102, 'Bob',     'bob@example.com',     'silver'),
    (103, 'Charlie', 'charlie@example.com', 'bronze'),
])
con.commit()
con.close()
print(f'✅  Database seeded at {DB}  (5 orders, 3 customers)')
# Out:
# ✅  Database seeded at data/retail.db  (5 orders, 3 customers)

# %% [markdown]
# ---
# ## Run 1 — Full Bronze Load
#
# dlt reads all orders (cursor starts at `2024-01-01`) and all customers (full scan + merge).
# Raw shards land at `data/bronze/{table}/`; bronze.py merges them to `data/bronze/{table}.parquet`.

# %%
# !medallion run retail --layer bronze
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   medallion  ·  retail  ·  bronze ingestion
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 📋  [config] bronze: retail/backend/bronze.yaml
# 📋  [config] silver: retail/backend/silver.yaml
# 📋  [config] gold  : retail/backend/gold.yaml
#
# ── Bronze ─────────────────────────────────────────────────
#
# ********************************************************************************
# > bronze [openmedallion.pipeline.nodes.bronze()] encountered an error          <
# > Node inputs:
# {'config': "{'pipeline': {'name': 'retail'}, 'paths': {'bronze..."}
# ********************************************************************************
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/libs/pyarrow.py", line 33, in <module>
#     import pyarrow
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 211, in _gather_metrics_and_close
#     normalizer.item_storage.close_writers(load_id, skip_flush=in_exception)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/storages/data_item_storage.py", line 88, in close_writers
#     writer.close(skip_flush=skip_flush)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 185, in close
#     self._flush_and_close_file(skip_flush=skip_flush)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 266, in _flush_and_close_file
#     self._flush_items(allow_empty_file)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 247, in _flush_items
#     self._writer = self.writer_cls(self._file, caps=self._caps)  # type: ignore[assignment]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/configuration/inject.py", line 281, in _wrap
#     return f(*bound_args.args, **bound_args.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/writers.py", line 322, in __init__
#     from dlt.common.libs.pyarrow import pyarrow
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/libs/pyarrow.py", line 40, in <module>
#     raise MissingDependencyException(
# dlt.common.exceptions.MissingDependencyException:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 562, in normalize
#     runner.run_pool(normalize_step.config, normalize_step)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/runners/pool_runner.py", line 253, in run_pool
#     while _run_func():
#           ^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/runners/pool_runner.py", line 246, in _run_func
#     run_metrics = run_f.run(cast(TExecutor, pool))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 351, in run
#     self.spool_schema_files(load_id, schema, schema_files)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 306, in spool_schema_files
#     self.spool_files(load_id, schema.clone(update_normalizers=True), map_f, files)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 251, in spool_files
#     raise pending_exc
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 196, in map_single
#     result = w_normalize_files(
#              ^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 273, in w_normalize_files
#     writer_metrics = _gather_metrics_and_close(parsed_file_name, in_exception=False)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 232, in _gather_metrics_and_close
#     raise NormalizeJobFailed(load_id, job_id, str(exc), writer_metrics)
# dlt.normalize.exceptions.NormalizeJobFailed: Job for `job_id=customers.63bc4e5685.typed-jsonl.gz` failed terminally in load with `load_id=1777494915.0553696` with message:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files..
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/execution/graph_functions.py", line 321, in execute_lifecycle_for_node
#     result = __node_(**__kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/node.py", line 282, in __call__
#     return self.callable(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/pipeline/nodes.py", line 49, in bronze
#     return BronzeLoader(config).load()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/pipeline/bronze.py", line 103, in load
#     info = pipeline.run(sources, loader_file_format="parquet")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 224, in _wrap
#     step_info = f(self, *args, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 272, in _wrap
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 769, in run
#     self.normalize()
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 224, in _wrap
#     step_info = f(self, *args, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 178, in _wrap
#     rv = f(self, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 272, in _wrap
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 570, in normalize
#     raise PipelineStepFailed(
# dlt.pipeline.exceptions.PipelineStepFailed: Pipeline execution failed at `step=normalize` when processing package with `load_id=1777494915.0553696` with exception:
#
# <class 'dlt.normalize.exceptions.NormalizeJobFailed'>
# Job for `job_id=customers.63bc4e5685.typed-jsonl.gz` failed terminally in load with `load_id=1777494915.0553696` with message:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files..
#
# Pending packages are left in the pipeline and will be re-tried on the next pipeline run. If you pass new data to extract to next run, it will be ignored. Run `dlt pipeline retail info` for more information or `dlt pipeline retail drop-pending-packages` to drop pending packages.
# -------------------------------------------------------------------
# Oh no an error! Need help with Hamilton?
# Join our slack and ask for help! https://join.slack.com/t/hamilton-opensource/shared_invite/zt-2niepkra8-DGKGf_tTYhXuJWBTXtIs4g
# -------------------------------------------------------------------
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/libs/pyarrow.py", line 33, in <module>
#     import pyarrow
# ModuleNotFoundError: No module named 'pyarrow'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 211, in _gather_metrics_and_close
#     normalizer.item_storage.close_writers(load_id, skip_flush=in_exception)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/storages/data_item_storage.py", line 88, in close_writers
#     writer.close(skip_flush=skip_flush)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 185, in close
#     self._flush_and_close_file(skip_flush=skip_flush)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 266, in _flush_and_close_file
#     self._flush_items(allow_empty_file)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/buffered.py", line 247, in _flush_items
#     self._writer = self.writer_cls(self._file, caps=self._caps)  # type: ignore[assignment]
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/configuration/inject.py", line 281, in _wrap
#     return f(*bound_args.args, **bound_args.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/data_writers/writers.py", line 322, in __init__
#     from dlt.common.libs.pyarrow import pyarrow
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/libs/pyarrow.py", line 40, in <module>
#     raise MissingDependencyException(
# dlt.common.exceptions.MissingDependencyException:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 562, in normalize
#     runner.run_pool(normalize_step.config, normalize_step)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/runners/pool_runner.py", line 253, in run_pool
#     while _run_func():
#           ^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/common/runners/pool_runner.py", line 246, in _run_func
#     run_metrics = run_f.run(cast(TExecutor, pool))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 351, in run
#     self.spool_schema_files(load_id, schema, schema_files)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 306, in spool_schema_files
#     self.spool_files(load_id, schema.clone(update_normalizers=True), map_f, files)
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 251, in spool_files
#     raise pending_exc
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/normalize.py", line 196, in map_single
#     result = w_normalize_files(
#              ^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 273, in w_normalize_files
#     writer_metrics = _gather_metrics_and_close(parsed_file_name, in_exception=False)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/normalize/worker.py", line 232, in _gather_metrics_and_close
#     raise NormalizeJobFailed(load_id, job_id, str(exc), writer_metrics)
# dlt.normalize.exceptions.NormalizeJobFailed: Job for `job_id=customers.63bc4e5685.typed-jsonl.gz` failed terminally in load with `load_id=1777494915.0553696` with message:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files..
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/venv/bin/medallion", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/cli/main.py", line 256, in main
#     _HANDLERS[_args.command](_args)
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/cli/main.py", line 116, in cmd_run
#     dr.execute(final_vars=final_vars, inputs=inputs, overrides=overrides)
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/driver.py", line 578, in execute
#     raise e
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/driver.py", line 565, in execute
#     outputs = self.__raw_execute(
#               ^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/driver.py", line 732, in __raw_execute
#     raise e
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/driver.py", line 723, in __raw_execute
#     results = self.graph_executor.execute(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/driver.py", line 161, in execute
#     fg.execute(nodes, memoized_computation, overrides, inputs, run_id=run_id)
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/graph.py", line 1146, in execute
#     return graph_functions.execute_subdag(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/execution/graph_functions.py", line 269, in execute_subdag
#     dfs_traverse(final_var_node, dep_type)
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/execution/graph_functions.py", line 241, in dfs_traverse
#     result = execute_lifecycle_for_node_partial(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/execution/graph_functions.py", line 321, in execute_lifecycle_for_node
#     result = __node_(**__kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/hamilton/node.py", line 282, in __call__
#     return self.callable(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/pipeline/nodes.py", line 49, in bronze
#     return BronzeLoader(config).load()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/openmedallion/pipeline/bronze.py", line 103, in load
#     info = pipeline.run(sources, loader_file_format="parquet")
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 224, in _wrap
#     step_info = f(self, *args, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 272, in _wrap
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 769, in run
#     self.normalize()
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 224, in _wrap
#     step_info = f(self, *args, **kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 178, in _wrap
#     rv = f(self, *args, **kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 272, in _wrap
#     return f(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/venv/lib/python3.12/site-packages/dlt/pipeline/pipeline.py", line 570, in normalize
#     raise PipelineStepFailed(
# dlt.pipeline.exceptions.PipelineStepFailed: Pipeline execution failed at `step=normalize` when processing package with `load_id=1777494915.0553696` with exception:
#
# <class 'dlt.normalize.exceptions.NormalizeJobFailed'>
# Job for `job_id=customers.63bc4e5685.typed-jsonl.gz` failed terminally in load with `load_id=1777494915.0553696` with message:
# You must install additional dependencies to run `dlt pyarrow helpers`. If you use pip you may do the following:
#
# pip install "dlt[parquet]"
#
# Install pyarrow to be allowed to load arrow tables, pandas DataFrames and to use parquet files..
#
# Pending packages are left in the pipeline and will be re-tried on the next pipeline run. If you pass new data to extract to next run, it will be ignored. Run `dlt pipeline retail info` for more information or `dlt pipeline retail drop-pending-packages` to drop pending packages.

# %%
bronze_dir = Path('data/bronze')

# Show merged bronze files (these are what silver reads)
for name in ('orders', 'customers'):
    path = bronze_dir / f'{name}.parquet'
    if path.exists():
        print(f'── data/bronze/{name}.parquet (merged, silver reads this) ──')
        print(pl.read_parquet(path))
        print()
    else:
        print(f'⚠️  data/bronze/{name}.parquet not found')

# Show dlt shard subdirectories
if bronze_dir.exists():
    shard_dirs = [d for d in sorted(bronze_dir.iterdir()) if d.is_dir()]
    if shard_dirs:
        print('── data/bronze/ shard subdirs (dlt internal) ──')
        for d in shard_dirs:
            shards = list(d.glob('*.parquet'))
            print(f'  {d.name}/  ({len(shards)} shard(s))')
# Out:
# ⚠️  data/bronze/orders.parquet not found
# ⚠️  data/bronze/customers.parquet not found

# %% [markdown]
# ## Run 1 — Silver + Gold

# %%
# !medallion run retail --layer silver
#!medallion run retail --layer gold
# Out:
# 📋  [config] loaded bronze: retail/backend/bronze.yaml
# 📋  [config] loaded silver: retail/backend/silver.yaml
# 📋  [config] loaded gold  : retail/backend/gold.yaml
# 🚀  Project  : retail
# 📋  Layer    : bronze → silver
# ⏭️   Bronze   : skipped (using existing files)
# ⚠️   [silver] missing bronze file: data/bronze/orders.parquet
# ⚠️   [silver] missing bronze file: data/bronze/customers.parquet
#
# ✅  bronze → silver complete.

# %%
gold = Path('data/gold/retail')

print('── customer_summary (Run 1) ──')
run1_summary = pl.read_parquet(gold / 'customer_summary.parquet').sort('customer_id')
print(run1_summary)

print('\n── pipeline_totals (Run 1) ──')
print(pl.read_parquet(gold / 'pipeline_totals.parquet'))

# %% [markdown]
# ---
# ## Delta: Add New Data
#
# Inserts 2 new orders (Feb 2024) and promotes Charlie from `bronze` to `platinum`.
#
# On the next bronze run:
# - **orders** (append): dlt reads only rows where `created_at > 2024-01-09` → 2 new rows
# - **customers** (merge): dlt upserts on `customer_id` → Charlie's tier updated in-place

# %%
con = sqlite3.connect('data/retail.db')
cur = con.cursor()

cur.executemany('INSERT OR REPLACE INTO orders VALUES (?,?,?,?)', [
    (6, 101,  90.00, '2024-02-01'),
    (7, 103, 450.00, '2024-02-02'),
])
cur.execute('UPDATE customers SET tier=? WHERE customer_id=?', ('platinum', 103))

con.commit()
con.close()
print('✅  Added 2 new orders (IDs 6, 7) and promoted Charlie → platinum')

# %% [markdown]
# ## Run 2 — Delta Bronze Load (incremental)
#
# Watch the output: dlt should load **only 2 rows** for orders, not 7.

# %%
# !medallion run retail --layer bronze

# %% [markdown]
# ## Run 2 — Silver + Gold

# %%
# !medallion run retail

# %%
print('── customer_summary comparison: Run 1 vs Run 2 ──')
run2_summary = pl.read_parquet(gold / 'customer_summary.parquet').sort('customer_id')

diff = run1_summary.join(run2_summary, on='customer_id', suffix='_run2')
print(diff)

print('\n── pipeline_totals (Run 2) ──')
print(pl.read_parquet(gold / 'pipeline_totals.parquet'))

print('\nKey observations:')
print('  • Charlie (103): total_orders 1 → 2, total_spent grew by $450')
print('  • Alice  (101): gained order #6 ($90)')
print('  • Bob    (102): unchanged — no new orders')

# %% [markdown]
# ## dlt Cursor State
#
# dlt saves the last-seen `created_at` value so the next run knows where to continue.
# All bronze output lives under `data/bronze/` — shards, dlt state, and merged parquets:

# %%
bronze_dir = Path('data/bronze')
if bronze_dir.exists():
    print('data/bronze/ contents:')
    merged = list(bronze_dir.glob('*.parquet'))
    for f in sorted(merged):
        print(f'  {f.name}  ← merged parquet (silver reads this)')
    for d in sorted(bronze_dir.iterdir()):
        if d.is_dir():
            shards = list(d.glob('*.parquet'))
            print(f'  {d.name}/  ({len(shards)} shard file(s))  ← dlt internal')
    print()
    print('Delete data/bronze/ to force a full reload on next run.')
else:
    print('data/bronze/ not found yet — run bronze first.')

# %% [markdown]
# ## Things to Try
#
# - **Force a full reload**: `rm -rf data/bronze/` then re-run bronze
# - **Add another delta**: extend the delta cell with order ID 8 and re-run
# - **Change initial_value**: edit `backend/bronze.yaml` → `initial_value: '2024-01-07'` and reload
